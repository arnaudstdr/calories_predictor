# %% [markdown]
# ### 1. Import des librairies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Chargement du dataset

# %%
df = pd.read_csv("../data/dataset_synthetique_calories.csv")
df.head()
# Out:
#     poids_kg   duree_min  vitesse_moyenne  distance_km  intensite  age  \
# 0  79.967142  126.887586        20.200860    42.720639  endurance   24
# 1  73.617357  115.616746        29.875255    57.567997       cool   30
# 2  81.476885   83.414509        27.351612    38.025354     rythme   25
# 3  90.230299  177.977287        15.720811    46.632455  endurance   39
# 4  72.658466  120.866223        30.483767    61.407630  endurance   57
#
#    fc_max  fc_moyenne  calories_brulees
# 0     196  135.273769       1546.232855
# 1     190  112.595584       1012.082708
# 2     195  137.876322       1059.216261
# 3     181  119.857877       1970.576011
# 4     163  114.115911       1237.556632

# %% [markdown]
# ### 3. Aperçu général

# %%
df.info()
df.describe()
df.isnull().sum()
df.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   poids_kg          500 non-null    float64
#  1   duree_min         500 non-null    float64
#  2   vitesse_moyenne   500 non-null    float64
#  3   distance_km       500 non-null    float64
#  4   intensite         500 non-null    object
#  5   age               500 non-null    int64
#  6   fc_max            500 non-null    int64
#  7   fc_moyenne        500 non-null    float64
#  8   calories_brulees  500 non-null    float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 35.3+ KB
# np.int64(0)

# %% [markdown]
# ### 4. Analyse des variables
# - Types de variables
# - distributions

# %%
df['intensite'].value_counts().plot(kind='bar')
sns.histplot(df['calories_brulees'], kde=True)
# Out:
# <Axes: xlabel='intensite', ylabel='Count'>

# %% [markdown]
# ### 5. Corrélations

# %%
corr = df.select_dtypes(include=np.number).corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ### 6. Relations clés (calories vs autres variables)

# %%
sns.pairplot(df, hue='intensite')

# %% [markdown]
# ### 7. Analyse par type d'intensité

# %%
sns.boxplot(data=df,x='intensite', y='calories_brulees')
# Out:
# <Axes: xlabel='intensite', ylabel='calories_brulees'>

# %% [markdown]
# ### 8. Features importantes à surveiller
#
# - `poids_kg`
# - `duree_min`
# - `distance_km`
# - `met`
